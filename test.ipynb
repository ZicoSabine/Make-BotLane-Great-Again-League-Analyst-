# %%
import pymongo # install pymongo into the venv
import json
import requests # install requests into the venv
import os
from dotenv import load_dotenv# install python-dotenv into the venv
from pymongo import MongoClient

# %%
# host locally
# client = MongoClient('mongodb://localhost:27017/')

# for MongoDB Atlas Cloud:
client = MongoClient("mongodb+srv://V1enna4:Butterking1@riotapi.fkzyig1.mongodb.net/")

# %%
# selecting database and collection
db = client['mydatabase']
collection = db['players']

# %%
load_dotenv()  # Load environment variables from .env file
riot_api_key = os.getenv("riot_api")

# %%
def getuserpuuid(gameName, tagLine):
    user_puuid = f"https://asia.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{gameName}/{tagLine}?api_key={riot_api_key}"
    return user_puuid

# %%
getuserpuuid("V1enna", "9849")
# Out:
# 'https://asia.api.riotgames.com/riot/account/v1/accounts/by-riot-id/V1enna/9849?api_key=RGAPI-e69b87e9-298c-4b5d-8255-7a1f0f021f7f'

# %%
puuid = json.loads(requests.get(getuserpuuid("V1enna", "9849")).text)['puuid']
print(puuid)
# Out:
# eOKalWbShPuyGI5mRbikYqoBFjRDhjJa9Gub32M2LbTMhqi_bgxxMouIwgXnJ76P5Y_XnotF4y36cQ

# %%
# inserting a new document into the collection
# get the data from RiotAPI first and then insert it into the collection
users = {
    "username",
    "role",
    "championPlayed",
    "duoPlayed",
    "enemyPlayed",
    "enemyDuoPlayed",
    "KDA",
    "CS",
    "win" # if the user won the game or not
}

# %%
# example insert
users = {
    "username": "Player1",
    "championPlayed": "Ashe",
    "duoPlayed": "Seraphine",
    "enemyPlayed": "Caitlyn",  
    "enemyDuoPlayed": "Lux",
    "KDA": 3.5,
    "CS": 150,
    "win": True
}
result = collection.insert_one(users)

# %%
users2 = {
    "username": "Player2",
    "championPlayed": "Mel",
    "duoPlayed": "Jhin",
    "enemyPlayed": "Senna",  
    "enemyDuoPlayed": "Tahm Kench",
    "KDA": 2,
    "CS": 170,
    "win": False
}
result = collection.insert_one(users2)

# %%
for coll_name in db.list_collection_names():
    coll = db[coll_name]
    print(f"Collection: {coll_name}")
    for doc in coll.find():
        print(doc)
    print()
# Out:
# Collection: players
# {'_id': ObjectId('6a61bfa3a9a7f0c7e48a2eb3'), 'username': 'Player1', 'championPlayed': 'Ashe', 'duoPlayed': 'Seraphine', 'enemyPlayed': 'Caitlyn', 'enemyDuoPlayed': 'Lux', 'KDA': 3.5, 'CS': 150, 'win': True}
# {'_id': ObjectId('6a61c027a9a7f0c7e48a2eb4'), 'username': 'Player2', 'championPlayed': 'Mel', 'duoPlayed': 'Jhin', 'enemyPlayed': 'Senna', 'enemyDuoPlayed': 'Tahm Kench', 'KDA': 2, 'CS': 170, 'win': False}
# {'_id': ObjectId('6a61c030a9a7f0c7e48a2eb5'), 'username': 'Player2', 'championPlayed': 'Mel', 'duoPlayed': 'Jhin', 'enemyPlayed': 'Senna', 'enemyDuoPlayed': 'Tahm Kench', 'KDA': 2, 'CS': 170, 'win': False}
